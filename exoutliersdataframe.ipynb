# %% [markdown]
# <a href="https://colab.research.google.com/github/Sudharsan-ai/exno1/blob/main/exoutliersdataframe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
x=[12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42,81, 84, 87, 90, 93, 96, 99, 148,200]

df = pd.DataFrame(x)
df
# Out:
#       0
# 0    12
# 1    15
# 2    18
# 3    21
# 4    24
# 5    27
# 6    30
# 7    33
# 8    36
# 9    39
# 10   42
# 11   81
# 12   84
# 13   87
# 14   90
# 15   93
# 16   96
# 17   99
# 18  148
# 19  200

# %%
sns.boxplot(data=df)
# Out:
# <Axes: >

# %%
sns.scatterplot(data=af)
# Out:
# <Axes: >

# %%
q1=df.quantile(0.25)
q3=df.quantile(0.75)
iqr=q3-q1
iqr
# Out:
# 0    64.5
# dtype: float64

# %%
l=q1-1.5*iqr
l
# Out:
# 0   -70.5
# dtype: float64

# %%
u=q3+1.5*iqr
u
# Out:
# 0    187.5
# dtype: float64

# %%
af=df[((df>=l)&(df<=u))]
af
# Out:
#        0
# 0   12.0
# 1   15.0
# 2   18.0
# 3   21.0
# 4   24.0
# 5   27.0
# 6   30.0
# 7   33.0
# 8   36.0
# 9   39.0
# 10  42.0
# 11  81.0
# 12  84.0
# 13  87.0
# 14  90.0
# 15  93.0
# 16  96.0
# 17  99.0
# 18   NaN

# %%
af.dropna()
# Out:
#        0
# 0   12.0
# 1   15.0
# 2   18.0
# 3   21.0
# 4   24.0
# 5   27.0
# 6   30.0
# 7   33.0
# 8   36.0
# 9   39.0
# 10  42.0
# 11  81.0
# 12  84.0
# 13  87.0
# 14  90.0
# 15  93.0
# 16  96.0
# 17  99.0

# %%
sns.boxplot(data=af)
# Out:
# <Axes: >
