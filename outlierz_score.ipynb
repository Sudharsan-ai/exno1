# %% [markdown]
# <a href="https://colab.research.google.com/github/Sudharsan-ai/exno1/blob/main/outlierz_score.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from scipy import stats
df = pd.read_csv('heights.csv')
df
# Out:
#        name  height
# 0     mohan     5.9
# 1     maria     5.2
# 2     sakib     5.1
# 3       tao     5.5
# 4     virat     4.9
# 5    khusbu     5.4
# 6    dmitry     6.2
# 7    selena     6.5
# 8      john     7.1
# 9     imran    14.5
# 10     jose     6.1
# 11  deepika     5.6
# 12   yoseph     1.2
# 13    binod     5.5

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    14 non-null     object
#  1   height  14 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 356.0+ bytes

# %%
import seaborn as sns
sns.boxplot(data=df)
# Out:
# <Axes: >

# %%
z = np.abs(stats.zscore(df['height']))
pd.DataFrame(z)
# Out:
#            0
# 0   0.055998
# 1   0.317320
# 2   0.354652
# 3   0.205325
# 4   0.429315
# 5   0.242656
# 6   0.055998
# 7   0.167993
# 8   0.391983
# 9   3.154532
# 10  0.018666
# 11  0.167993
# 12  1.810589
# 13  0.205325

# %%
df1=df[z<3]
df1
# Out:
#        name  height
# 0     mohan     5.9
# 1     maria     5.2
# 2     sakib     5.1
# 3       tao     5.5
# 4     virat     4.9
# 5    khusbu     5.4
# 6    dmitry     6.2
# 7    selena     6.5
# 8      john     7.1
# 10     jose     6.1
# 11  deepika     5.6
# 12   yoseph     1.2
# 13    binod     5.5
